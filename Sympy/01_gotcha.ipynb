# %%
from sympy.plotting import *
from sympy import symbols
from sympy.functions import sin

import math

x,y = symbols("x y")
p2 = plot3d((x**2+y**2),(x,-10,10),(y,-10,10))
x,y = symbols("x y")
p1 = plot3d(sin(x*y),(x,-3,3),(y,-2,2))

# %%
import sympy as sp

sp.sqrt(3)
# Out:
# sqrt(3)

# %%
import sympy as sp
from sympy import symbols
x,y = symbols('x y')
expr = x + 2*y
sp.factor(x*expr)
# Out:
# x*(x + 2*y)

# %%
from sympy import *
x, t, z, nu = symbols("x t z nu")
init_printing(use_unicode=True)
expr1 = sin(x)*exp(x)
diff(expr1,x)
# Out:
#  x           x
# ℯ ⋅sin(x) + ℯ ⋅cos(x)

# %%
integrate(expr1,x)
# Out:
#  x           x
# ℯ ⋅sin(x)   ℯ ⋅cos(x)
# ───────── - ─────────
#     2           2

# %%
integrate(sin(x**2), (x,-oo, oo))
# Out:
# √2⋅√π
# ─────
#   2

# %%
limit(sin(x)/x,x,0)
# Out:
# 1

# %%
solve(x**2 -2 ,x)
# Out:
# [-√2, √2]

# %%
y = Function('y')
dsolve(Eq(y(t).diff(t,t)-y(t), exp(t)),y(t))
# Out:
#            -t   ⎛     t⎞  t
# y(t) = C₂⋅ℯ   + ⎜C₁ + ─⎟⋅ℯ
#                 ⎝     2⎠

# %%
Matrix([[1,2],[2,2]]).eigenvals()
# Out:
# ⎧3   √17     3   √17   ⎫
# ⎨─ - ───: 1, ─ + ───: 1⎬
# ⎩2    2      2    2    ⎭

# %%
x = symbols('x')
expr = x + 1
expr.subs(x,2)
# Out:
# 3

# %%
Eq(x+1,4)
# Out:
# x + 1 = 4

# %%
a,b = symbols("a b")
a = (x + 1)**2
b = x**2 + 2*x + 1
simplify(a-b)
# Out:
# 0

# %%
a = cos(x)**2 -sin(x)**2
b = cos(2*x)
a.equals(b)
# Out:
# True

# %%
True ^ True
# Out:
# False

# %%
Xor(x,y)
# Out:
# y ⊻ x

# %%
type(Integer(1)+1)
# Out:
# sympy.core.numbers.Integer

# %%
type(1+1)
# Out:
# int

# %%
Integer(1)
# Out:
# 1

# %%
1/2
# Out:
# 0.5

# %%
Rational(1,4)
# Out:
# 1/4
