# %%
import matplotlib.pyplot as plt
plt.subplot(3,2,4)
plt.plot([0,2,4,6,8],[2,3,5,2,3])
plt.ylabel("grade")
plt.ylabel([-1,10,0,6])
#lt.savefig('test',dpi=600)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

def f(t):
    return np.exp(-t) * np.cos(2*np.pi*t)

a = np.arange(0.0,5.0,0.02)

plt.subplot(211)
plt.plot(a,f(a))

plt.subplot(212)
plt.plot(a, np.cos(2*np.pi*a),'r--')
plt.show()

# %% [markdown]
# ## plt.plot(x, y, format_string, **kwargs)
# 1. x : X轴数据，列表或数组，可选
#
# 2. y : Y轴数据，列表或数组
#
# 3.  format_string: 控制曲线的格式字符串，可选
# 颜色字符、风格字符和标记字符
#
# 4. **kwargs : 第二组或更多(x,y,format_string)
#     1. color : 控制颜色, color='green'
#     2. linestyle : 线条风格, linestyle='dashed'
#     3. marker : 标记风格, marker='o'
#     4. markerfacecolor: 标记颜色, markerfacecolor='blue'
#     5. markersize : 标记尺寸, markersize=20
#
# ![](http://oss.flameszj.top/img/20200506002104.png)
# ![](http://oss.flameszj.top/img/20200506002128.png)
# ![](http://oss.flameszj.top/img/20200506002142.png)
#
# ## Pyplot的中文显示
# pyplot并不默认支持中文显示，需要rcParams修改字体实现
#
# |属性|说明|
# |:--:|:--:|
# |'font.family'| 用于显示字体的名字|
# |'font.style'| 字体风格，正常'normal'或斜体'italic'|
# |'font.size'| 字体大小，整数字号或者'large'、'x‐small'|
#
# |中文字体|说明|
# |:--:|:--:|
# |'SimHei'| 中文黑体|
# |'Kaiti'| 中文楷体|
# |'LiSu'| 中文隶书|
# |'FangSong'| 中文仿宋|
# |'YouYuan'| 中文幼圆|
# |'STSong'| 华文宋体|

# %%
import matplotlib.pyplot as plt 
import matplotlib 

matplotlib.rcParams['font.family']='SimHei'
plt.plot([3,1,4,5,2])
#plt.xlabel('xlabel',fontproperties='DejaVu Sans')
plt.xlabel('xlabel',fontsize=20,fontproperties='Times New Roman')
plt.ylabel('y标签',fontsize=20)
plt.show()

# %% [markdown]
# ## Pyplot的文本显示函数
# |函数|说明|
# |:--:|:--:|
# |plt.xlabel() |对X轴增加文本标签|
# |plt.ylabel()| 对Y轴增加文本标签|
# |plt.title() |对图形整体增加文本标签|
# |plt.text()| 在任意位置增加文本|
# |plt.annotate()| 在图形中增加带箭头的注解|
#
# plt.annotate(s, xy=arrow_crd, xytext=text_crd, arrowprops=dict)

# %%
import numpy as np
import matplotlib.pyplot as plt
 
a = np.arange(0.0,5.0,0.01)
plt.plot(a,np.cos(2*np.pi*a),'r--')

plt.xlabel('X:Time',fontsize=15,color='green')
plt.ylabel('Y:Amplitude',fontsize=15,color='red')
plt.title(r'sin function: $y=cos(2\pi x)$',fontsize=25)
plt.text(2,1,r'$\mu=100$',fontsize=15)
plt.annotate(r'$\mu=100$',xy=(2,1),xytext=(3,1.5),arrowprops=dict(facecolor='black',shrink=0.1,width=2))

plt.axis([-1,6,-2,2])
plt.grid(True)
plt.show()

# %% [markdown]
# ## pyplotn子绘图区
# plt.subplot2grid(GridSpec, CurSpec, colspan=1, rowspan=1)
#
# 理念：设定网格，选中网格，确定选中行列区域数量，编号从0开始
#
# plt.subplot2grid((3,3), (1,0), colspan=2)
#
# **GridSpec** 类
# ![](http://oss.flameszj.top/img/20200506010116.png)
