# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
pic = plt.imread('20200424171442.png')
plt.imshow(pic)

# %%
pic1 = pic[::-1,::-1]
pic3 = pic[::x,::,::-1]
plt.imshow(pic3)

# %%
import pandas as pd
from pandas import Series,DataFrame
import numpy as np
import matplotlib.pyplot as plt

# %%
nd = np.array([1,2,3,4,5,6])
s = Series(nd)
s.index = list('abcdef')
s
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# f    6
# dtype: int64

# %%
s = Series(np.random.randint(0,5,5),index=list('abcde'))
s
# Out:
# a    3
# b    0
# c    4
# d    3
# e    3
# dtype: int64

# %%
s2 = Series({'a':1,'b':2,'c':3,'d':32})
s2
# Out:
# a     1
# b     2
# c     3
# d    32
# dtype: int64

# %%
s = Series(np.random.random(10),index = list('abcdefghig'))
s
# Out:
# a    0.883444
# b    0.220797
# c    0.880774
# d    0.927403
# e    0.264766
# f    0.588538
# g    0.375329
# h    0.034586
# i    0.947656
# g    0.090612
# dtype: float64

# %%
s['a']
# Out:
# 0.8834441066135345

# %%
s.loc['c']
# Out:
# 0.8807736563712

# %%
s.iloc[0]
# Out:
# 0.8834441066135345

# %%
s.iloc[1:4]
# Out:
# b    0.220797
# c    0.880774
# d    0.927403
# dtype: float64

# %%
display(s.shape,s.size,s.values,s.index)
# Out:
# (10,)
# 10
# array([0.88344411, 0.22079747, 0.88077366, 0.92740264, 0.26476599,
#        0.5885376 , 0.37532925, 0.03458578, 0.94765609, 0.0906119 ])
# Index(['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'g'], dtype='object')

# %%
df = pd.read_csv('test.csv')
df
# Out:
#      姓名   升高  年龄  体重
# 0   sun  175  28  82
# 1   kai  170  28  75
# 2  huai  180  30  85
# 3   shi  169  26  70
# 4    he  177  26  80

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
height = df['升高']

# %%
height.head(3)
# Out:
# 0    175
# 1    170
# 2    180
# Name: 升高, dtype: int64

# %%
s = Series([1,2,None,np.nan],index=list('abcd'))
s
# Out:
# a    1.0
# b    2.0
# c    NaN
# d    NaN
# dtype: float64

# %%
s.notnull()
# Out:
# a     True
# b     True
# c    False
# d    False
# dtype: bool

# %%
s.add(10,fill_value=0)
# Out:
# a    11.0
# b    12.0
# c    10.0
# d    10.0
# dtype: float64

# %%
s1 = Series([2,3,4,5],index = [0,1,2,3])
s2 = Series([6,5,4,3],index = [2,3,4,5])

# %%
s1 + s2
# Out:
# 0     NaN
# 1     NaN
# 2    10.0
# 3    10.0
# 4     NaN
# 5     NaN
# dtype: float64

# %%
s1.add(s2,fill_value=0)
# Out:
# 0     2.0
# 1     3.0
# 2    10.0
# 3    10.0
# 4     4.0
# 5     3.0
# dtype: float64

# %%
df = DataFrame({'height':[175,180,169,188],
                'age':np.random.randint(18,25,size=4),
                'sex':['male','female','male','female'],
               'weight':[65,50,77,72]},
               index=list('abcd'),
               columns=['height','age','sex','weight'])
df
# Out:
#    height  age     sex  weight
# a     175   20    male      65
# b     180   22  female      50
# c     169   20    male      77
# d     188   19  female      72

# %%
display(df.values,df.shape,df.columns,df.index)
# Out:
# array([[175, 20, 'male', 65],
#        [180, 22, 'female', 50],
#        [169, 20, 'male', 77],
#        [188, 19, 'female', 72]], dtype=object)
# (4, 4)
# Index(['height', 'age', 'sex', 'weight'], dtype='object')
# Index(['a', 'b', 'c', 'd'], dtype='object')

# %%
df['age'] #访问列时可以用字典的方式或者属性的方式
# Out:
# a    20
# b    22
# c    20
# d    19
# Name: age, dtype: int64

# %%
df.age #对于DataFrame，列名就相当于属性
# Out:
# a    20
# b    22
# c    20
# d    19
# Name: age, dtype: int64

# %%
df.loc['a'] #对行进行索引
# Out:
# height     175
# age         20
# sex       male
# weight      65
# Name: a, dtype: object

# %%
df.loc['a':'c']
# Out:
#    height  age     sex  weight
# a     175   20    male      65
# b     180   22  female      50
# c     169   20    male      77

# %%
df.iloc[1:3]
# Out:
#    height  age     sex  weight
# b     180   22  female      50
# c     169   20    male      77

# %%
df['sex'] #索引表示的是列索引，切片表示的是行切片
# Out:
# a      male
# b    female
# c      male
# d    female
# Name: sex, dtype: object

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-72-580fb5cdfa6c> in <module>
# ----> 1 a = np.ix_(n)
#
# <__array_function__ internals> in ix_(*args, **kwargs)
#
# ~/miniconda3/lib/python3.7/site-packages/numpy/lib/index_tricks.py in ix_(*args)
#     101                 new = new.astype(_nx.intp)
#     102         if new.ndim != 1:
# --> 103             raise ValueError("Cross index must be 1 dimensional")
#     104         if issubdtype(new.dtype, _nx.bool_):
#     105             new, = new.nonzero()
#
# ValueError: Cross index must be 1 dimensional

# %%
df1 = DataFrame(np.random.randint(90,150,size=(4,4)),
               index = ['Mike','Hellen','Kate','Tony'],
               columns=['chinese','math','english','python'])
df1
# Out:
#         chinese  math  english  python
# Mike        103   126      141     115
# Hellen      127   122      117     147
# Kate        140   116      118     149
# Tony        134   102      125     122

# %%
df2 = DataFrame(np.random.randint(90,150,size=(5,4)),
               index = ['Mike','Hellen','Kate','Tony','Koby'],
               columns=['chinese','math','english','python'])
df2
# Out:
#         chinese  math  english  python
# Mike        130   130      117     136
# Hellen       91   107       94     118
# Kate        129   122      121     130
# Tony        136   100      142     135
# Koby        135    97       97     142

# %%
df1.add(df2,fill_value=0)
# Out:
#         chinese   math  english  python
# Hellen    218.0  229.0    211.0   265.0
# Kate      269.0  238.0    239.0   279.0
# Koby      135.0   97.0     97.0   142.0
# Mike      233.0  256.0    258.0   251.0
# Tony      270.0  202.0    267.0   257.0

# %%
df = DataFrame({'age':[20,21,23,19,22],'salary':[10000,11000,8000,9000,12000]},
              index=['Mike','Kitty','Trump','Obama','Tesla'],
              columns=['age','salary','work'])
df
# Out:
#        age  salary work
# Mike    20   10000  NaN
# Kitty   21   11000  NaN
# Trump   23    8000  NaN
# Obama   19    9000  NaN
# Tesla   22   12000  NaN

# %%
df.work['Kitty','Obama']='Python2'
df
# Out:
# /root/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /root/miniconda3/lib/python3.7/site-packages/pandas/core/indexing.py:671: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
#        age  salary     work
# Mike    20   10000      NaN
# Kitty   21   11000  Python2
# Trump   23    8000      NaN
# Obama   19    9000  Python2
# Tesla   22   12000      NaN

# %%
s1 = df.isnull().any(axis=1)

# %%
df[s1]
# Out:
#        age  salary work
# Mike    20   10000  NaN
# Trump   23    8000  NaN
# Tesla   22   12000  NaN

# %%
s2 = df.notnull().all(axis=1) #清洗无效数据
df[s2]
# Out:
#        age  salary     work
# Kitty   21   11000  Python2
# Obama   19    9000  Python2

# %%
df.dropna(axis=0)
# Out:
#        age  salary     work
# Kitty   21   11000  Python2
# Obama   19    9000  Python2

# %%
df.dropna(how='all')
# Out:
#        age  salary     work
# Mike    20   10000      NaN
# Kitty   21   11000  Python2
# Trump   23    8000      NaN
# Obama   19    9000  Python2
# Tesla   22   12000      NaN

# %%
df.fillna(value='Java')
# Out:
#        age  salary     work
# Mike    20   10000     Java
# Kitty   21   11000  Python2
# Trump   23    8000     Java
# Obama   19    9000  Python2
# Tesla   22   12000     Java

# %%
df.fillna(method='backfill')
# Out:
#        age  salary     work
# Mike    20   10000  Python2
# Kitty   21   11000  Python2
# Trump   23    8000  Python2
# Obama   19    9000  Python2
# Tesla   22   12000      NaN
